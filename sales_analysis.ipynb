# %%
import pandas as pd

df = pd.read_csv('clean_customer_behavior_dataset.csv')
total_revenue = df['monthly_income_ghs'].sum()

print(f"Total Revenue is: GHS{total_revenue}")
# Out:
# Total Revenue is: GHS7843.274744.393589.954720.39<bound method Series.median of 0       7843.27
# 1       4744.39
# 2       3589.95
# 3       4720.39
# 4           NaN
# 5       5440.28
# 6       6226.43
# 7        592.57
# 8       9446.60
# 9       7419.09
# 10      4284.78
# 11      3082.23
# 12      5219.82
# 13      6367.29
# 14      7241.31
# 15      5303.25
# 16      2578.82
# 17      2676.04
# 18      7845.07
# 19      6597.42
# 20      5682.44
# 21      2399.60
# 22      4075.69
# 23     12790.59
# 24      8188.71
# 25      4080.10
# 26      1835.27
# 27      6379.54
# 28      6041.66
# 29      4362.09
# 30      2775.80
# 31      6844.68
# 32      5141.86
# 33      5167.67
# 34      9193.79
# 35      7371.46
# 36      8215.71
# 37      1219.18
# 38      8462.42
# 39      6139.34
# 40      3836.66
# 41      9371.65
# 42      4955.12
# 43      7531.03
# 44      4639.03
# 45      3908.70
# 46      6112.64
# 47      6644.90
# 48      6659.82
# 49      2450.48
# 50      5076.75
# ...

# %%
print(df.columns.tolist())
# Out:
# ['customer_id', 'age', 'monthly_income_ghs', 'monthly_visits', 'annual_spend_ghs', 'segment', 'region', 'channel', 'satisfaction_score', 'returned_item', 'signup_date']

# %%
top_5_customers = df.sort_values(by= 'annual_spend', ascending= False).head(5)

top_5_customers = df.sort_values(
    by='annual_spend_ghs',
    ascending=False
).head(5)

print("Top 5 customers:")
print(top_5_customers[['customer_id', 'annual_spend_ghs', 'segment', 'region']])
print(top_5_customers[['customer_id', 'annual spend', 'segment','region']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 top_5_customers = df.sort_values(by= 'annual_spend', ascending= False).head(5)
#       2
#       3 top_5_customers = df.sort_values(
#       4     by='annual_spend_ghs',
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:8361, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8357             )
#    8358         elif by:
#    8359             # len(by) == 1
#    8360
# -> 8361             k = self._get_label_or_level_values(by[0], axis=axis)
#    8362
#    8363             # need to rewrap column in Series to apply key function
#    8364             if key is not None:
#
# ...
